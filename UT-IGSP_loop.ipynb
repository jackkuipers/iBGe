# %%
kk = 3
timey = [0]*100
for seedy in range(100):
    seed_number = seedy + 101
    exec(open("./UT-IGSP.py").read())
    timey[seedy] = time_taken
pandas.DataFrame(timey).to_csv("".join([dir_name, "/", f_name, "_UT-IGSP_times.csv"]), header=False, index=False)
# Out:
# 101
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 785.2964019775391
# 102
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 957.3662440776825
# 103
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 1064.701534986496
# 104
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 471.8468539714813
# 105
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 744.399248123169
# 106
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 716.352156162262
# 107
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 247.00043201446533
# 108
# 2.48e-08
# 1.11e-07
# 4.98e-07
# 2.23e-06
# 1e-05
# 1.65e-05
# 2.72e-05
# 4.48e-05
# 7.39e-05
# 463.2824740409851
# 109
# 2.48e-08
# ...
